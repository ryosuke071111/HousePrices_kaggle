# %%
import numpy as np
import pandas as pd
from sklearn import *

# %%
train = pd.read_csv('./all/train.csv')
test = pd.read_csv('./all/test.csv')

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
def missing_value(df):
    null_val = df.isnull().sum()
    percent = 100 * df.isnull().sum()/len(df)
    missing_table = pd.concat([null_val, percent], axis=1)
    missing_tabler_ren_columns = missing_table.rename(
    columns = {0:"欠損数", 1: "%"})
    return missing_tabler_ren_columns

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# ### カテゴリ変数に変換（train）

# %%
# MSZoning
train['MSZoning'] = train['MSZoning'].replace('A', 0)
train['MSZoning'] = train['MSZoning'].replace(['C', 'C (all)'], 1)
train['MSZoning'] = train['MSZoning'].replace('FV', 2)
train['MSZoning'] = train['MSZoning'].replace('I', 3)
train['MSZoning'] = train['MSZoning'].replace('RH', 4)
train['MSZoning'] = train['MSZoning'].replace('RL', 5)
train['MSZoning'] = train['MSZoning'].replace('RP', 6)
train['MSZoning'] = train['MSZoning'].replace('RM', 7)

#Street
train['Street'] = train['Street'].replace('Grvl', 0)
train['Street'] = train['Street'].replace('Pave', 1)

# Alley
train['Alley'] = train['Alley'].replace('Grvl',0 )
train['Alley'] = train['Alley'].replace('Pave',1 )
train['Alley'] = train['Alley'].fillna(2 )

# LotShape
train['LotShape'] = train['LotShape'].replace('Reg', 0)
train['LotShape'] = train['LotShape'].replace('IR1', 1)
train['LotShape'] = train['LotShape'].replace('IR2', 2)
train['LotShape'] = train['LotShape'].replace('IR3', 3)

#LandContour
train['LandContour'] = train['LandContour'].replace('Lvl', 0)
train['LandContour'] = train['LandContour'].replace('Bnk',1 )
train['LandContour'] = train['LandContour'].replace('HLS', 2)
train['LandContour'] = train['LandContour'].replace('Low', 3)

#Utilities
train['Utilities'] = train['Utilities'].replace('AllPub',0 )
train['Utilities'] = train['Utilities'].replace('NoSewr', 1)
train['Utilities'] = train['Utilities'].replace('NoSeWa', 2)
train['Utilities'] = train['Utilities'].replace('ELO', 3)

# LotConfing
train['LotConfig'] = train['LotConfig'].replace('Inside', 0)
train['LotConfig'] = train['LotConfig'].replace('Corner', 1)
train['LotConfig'] = train['LotConfig'].replace('CulDSac',2 )
train['LotConfig'] = train['LotConfig'].replace('FR2',3 )
train['LotConfig'] = train['LotConfig'].replace('FR3', 4)


#LandSlope
train['LandSlope'] = train['LandSlope'].replace('Gtl', 0)
train['LandSlope'] = train['LandSlope'].replace('Mod', 1)
train['LandSlope'] = train['LandSlope'].replace('Sev', 2)

#Neighborhood
train['Neighborhood'] = train['Neighborhood'].replace('Blmngtn', 0 )
train['Neighborhood'] = train['Neighborhood'].replace('Blueste', 1)
train['Neighborhood'] = train['Neighborhood'].replace('BrDale', 2)
train['Neighborhood'] = train['Neighborhood'].replace('BrkSide', 3)
train['Neighborhood'] = train['Neighborhood'].replace('ClearCr', 4)
train['Neighborhood'] = train['Neighborhood'].replace('CollgCr', 5)
train['Neighborhood'] = train['Neighborhood'].replace('Crawfor', 6)
train['Neighborhood'] = train['Neighborhood'].replace('Edwards', 7)
train['Neighborhood'] = train['Neighborhood'].replace('Gilbert', 8)
train['Neighborhood'] = train['Neighborhood'].replace('IDOTRR',9 )
train['Neighborhood'] = train['Neighborhood'].replace('MeadowV',10 )
train['Neighborhood'] = train['Neighborhood'].replace('Mitchel', 11)
train['Neighborhood'] = train['Neighborhood'].replace('Names', 12)
train['Neighborhood'] = train['Neighborhood'].replace('NAmes', 12)
train['Neighborhood'] = train['Neighborhood'].replace('NWAmes', 12)
train['Neighborhood'] = train['Neighborhood'].replace('NoRidge', 13)
train['Neighborhood'] = train['Neighborhood'].replace('NPkVill', 14)
train['Neighborhood'] = train['Neighborhood'].replace('NridgHt', 15)
train['Neighborhood'] = train['Neighborhood'].replace('NtAmes', 16)
train['Neighborhood'] = train['Neighborhood'].replace('OldTown', 17)
train['Neighborhood'] = train['Neighborhood'].replace('SWISU', 18)
train['Neighborhood'] = train['Neighborhood'].replace('Sawyer', 19)
train['Neighborhood'] = train['Neighborhood'].replace('SawyerW', 20)
train['Neighborhood'] = train['Neighborhood'].replace('Somerst', 21)
train['Neighborhood'] = train['Neighborhood'].replace('StoneBr', 22)
train['Neighborhood'] = train['Neighborhood'].replace('Timber', 23)
train['Neighborhood'] = train['Neighborhood'].replace('Veenker', 24)


#Condition1
train['Condition1'] = train['Condition1'].replace('Artery', 0)
train['Condition1'] = train['Condition1'].replace('Feedr', 1)
train['Condition1'] = train['Condition1'].replace('Norm', 2)
train['Condition1'] = train['Condition1'].replace('RRNn', 3)
train['Condition1'] = train['Condition1'].replace('RRAn', 4)
train['Condition1'] = train['Condition1'].replace('PosN', 5)
train['Condition1'] = train['Condition1'].replace('PosA', 6)
train['Condition1'] = train['Condition1'].replace('RRNe', 7)
train['Condition1'] = train['Condition1'].replace('RRAe', 8)

#Condition2
train['Condition2'] = train['Condition2'].replace('Artery', 0)
train['Condition2'] = train['Condition2'].replace('Feedr', 1)
train['Condition2'] = train['Condition2'].replace('Norm', 2)
train['Condition2'] = train['Condition2'].replace('RRNn', 3)
train['Condition2'] = train['Condition2'].replace('RRAn', 4)
train['Condition2'] = train['Condition2'].replace('PosN', 5)
train['Condition2'] = train['Condition2'].replace('PosA', 6)
train['Condition2'] = train['Condition2'].replace('RRNe', 7)
train['Condition2'] = train['Condition2'].replace('RRAe', 8)

#BldgType
train['BldgType'] = train['BldgType'].replace('1Fam', 0)
train['BldgType'] = train['BldgType'].replace('2fmCon',1 )
train['BldgType'] = train['BldgType'].replace('2FmCon',1 )
train['BldgType'] = train['BldgType'].replace('Duplex', 2)
train['BldgType'] = train['BldgType'].replace('Duplx', 2)
train['BldgType'] = train['BldgType'].replace('Twnhs', 3)
train['BldgType'] = train['BldgType'].replace('TwnhsE', 3)
train['BldgType'] = train['BldgType'].replace('TwnhsI', 4)

#HouseStyle
train['HouseStyle'] = train['HouseStyle'].replace('1Story', 0)
train['HouseStyle'] = train['HouseStyle'].replace('1.5Fin', 1)
train['HouseStyle'] = train['HouseStyle'].replace('1.5Unf', 2)
train['HouseStyle'] = train['HouseStyle'].replace('2Story', 3)
train['HouseStyle'] = train['HouseStyle'].replace('2.5Fin', 4)
train['HouseStyle'] = train['HouseStyle'].replace('2.5Unf', 5)
train['HouseStyle'] = train['HouseStyle'].replace('SFoyer', 6)
train['HouseStyle'] = train['HouseStyle'].replace('SLvl', 7)

#RoofStyle
train['RoofStyle'] = train['RoofStyle'].replace('Flat',0 )
train['RoofStyle'] = train['RoofStyle'].replace('Gable', 1)
train['RoofStyle'] = train['RoofStyle'].replace('Gambrel', 2)
train['RoofStyle'] = train['RoofStyle'].replace('Hip',3 )
train['RoofStyle'] = train['RoofStyle'].replace('Mansard',4 )
train['RoofStyle'] = train['RoofStyle'].replace('Shed', 5)

#RoofMatl
train['RoofMatl'] = train['RoofMatl'].replace('ClyTile', 0)
train['RoofMatl'] = train['RoofMatl'].replace('CompShg',1 )
train['RoofMatl'] = train['RoofMatl'].replace('Membran', 2)
train['RoofMatl'] = train['RoofMatl'].replace('Metal', 3)
train['RoofMatl'] = train['RoofMatl'].replace('Roll', 4)
train['RoofMatl'] = train['RoofMatl'].replace('Tar&Grv', 5)
train['RoofMatl'] = train['RoofMatl'].replace('WdShake', 6)
train['RoofMatl'] = train['RoofMatl'].replace('WdShngl', 7)

#Exterior1st
train['Exterior1st'] = train['Exterior1st'].replace('AsbShng', 0)
train['Exterior1st'] = train['Exterior1st'].replace('AsphShn', 1)
train['Exterior1st'] = train['Exterior1st'].replace('BrkComm', 2)
train['Exterior1st'] = train['Exterior1st'].replace('BrkFace', 3)
train['Exterior1st'] = train['Exterior1st'].replace('CBlock', 4)
train['Exterior1st'] = train['Exterior1st'].replace('CemntBd', 5)
train['Exterior1st'] = train['Exterior1st'].replace('HdBoard', 6)
train['Exterior1st'] = train['Exterior1st'].replace('ImStucc', 7)
train['Exterior1st'] = train['Exterior1st'].replace('MetalSd', 8)
train['Exterior1st'] = train['Exterior1st'].replace('Other', 9)
train['Exterior1st'] = train['Exterior1st'].replace('Plywood', 10)
train['Exterior1st'] = train['Exterior1st'].replace('PreCast', 11)
train['Exterior1st'] = train['Exterior1st'].replace('Stone', 12)
train['Exterior1st'] = train['Exterior1st'].replace('Stucco', 13)
train['Exterior1st'] = train['Exterior1st'].replace('VinylSd', 14)
train['Exterior1st'] = train['Exterior1st'].replace('Wd Sdng', 15)
train['Exterior1st'] = train['Exterior1st'].replace('WdShing', 16)


#Exterior2nd
train['Exterior2nd'] = train['Exterior2nd'].replace('AsbShng', 0)
train['Exterior2nd'] = train['Exterior2nd'].replace('AsphShn', 1)
train['Exterior2nd'] = train['Exterior2nd'].replace('BrkComm', 2)
train['Exterior2nd'] = train['Exterior2nd'].replace('Brk Cmn', 2)
train['Exterior2nd'] = train['Exterior2nd'].replace('Brk Cmm', 2)
train['Exterior2nd'] = train['Exterior2nd'].replace('BrkFace', 3)
train['Exterior2nd'] = train['Exterior2nd'].replace('CBlock', 4)
train['Exterior2nd'] = train['Exterior2nd'].replace('CemntBd', 5)
train['Exterior2nd'] = train['Exterior2nd'].replace('CmentBd', 5)
train['Exterior2nd'] = train['Exterior2nd'].replace('HdBoard', 6)
train['Exterior2nd'] = train['Exterior2nd'].replace('ImStucc', 7)
train['Exterior2nd'] = train['Exterior2nd'].replace('MetalSd', 8)
train['Exterior2nd'] = train['Exterior2nd'].replace('Other', 9)
train['Exterior2nd'] = train['Exterior2nd'].replace('Plywood', 10)
train['Exterior2nd'] = train['Exterior2nd'].replace('PreCast', 11)
train['Exterior2nd'] = train['Exterior2nd'].replace('Stone', 12)
train['Exterior2nd'] = train['Exterior2nd'].replace('Stucco', 13)
train['Exterior2nd'] = train['Exterior2nd'].replace('VinylSd', 14)
train['Exterior2nd'] = train['Exterior2nd'].replace('Wd Sdng', 15)
train['Exterior2nd'] = train['Exterior2nd'].replace('WdShing', 16)
train['Exterior2nd'] = train['Exterior2nd'].replace('Wd Shng', 16)

#MasVnrType
train['MasVnrType'] = train['MasVnrType'].replace('BrkCmn', 0)
train['MasVnrType'] = train['MasVnrType'].replace('BrkFace', 1)
train['MasVnrType'] = train['MasVnrType'].replace('CBlock', 2)
train['MasVnrType'] = train['MasVnrType'].fillna(3)
train['MasVnrType'] = train['MasVnrType'].replace('None', 3)
train['MasVnrType'] = train['MasVnrType'].replace('Stone', 4)


#ExterQual
train['ExterQual'] = train['ExterQual'].replace('Ex', 0).replace('Gd',1 ).replace('TA', 2).replace('Fa', 3).replace('Po', 4)

#ExterCond
train['ExterCond'] = train['ExterCond'].replace('Ex', 0).replace('Gd',1 ).replace('TA', 2).replace('Fa', 3).replace('Po', 4)

#Foundation
train['Foundation'] = train['Foundation'].replace('BrkTil', 0).replace('CBlock',1 ).replace('PConc', 2).replace('Slab', 3).replace('Stone', 4).replace('Wood', 5)

#BsmtQual
train['BsmtQual'] = train['BsmtQual'].replace('Ex', 0).replace('Gd',1 ).replace('TA', 2).replace('Fa', 3).replace('Po', 4).fillna(5)

#BsmtCond
train['BsmtCond'] = train['BsmtCond'].replace('Ex', 0).replace('Gd',1 ).replace('TA', 2).replace('Fa', 3).replace('Po', 4).fillna(5)


#BsmtExposure
train['BsmtExposure'] = train['BsmtExposure'].replace('Gd', 0).replace('Av',1 ).replace('Mn', 2).replace('No', 3).fillna(4)


#BsmtFinType1
train['BsmtFinType1'] = train['BsmtFinType1'].replace('GLQ', 0).replace('ALQ',1 ).replace('BLQ', 2).replace('Rec', 3).replace('LwQ', 4).replace('Unf', 5).fillna(6)


#BsmtFinType2
train['BsmtFinType2'] = train['BsmtFinType1'].replace('GLQ', 0).replace('ALQ',1 ).replace('BLQ', 2).replace('Rec', 3).replace('LwQ', 4).replace('Unf', 5).fillna(6)


#Heating
train['Heating'] = train['Heating'].replace('Floor', 0).replace('GasA',1 ).replace('GasW', 2).replace('Grav', 3).replace('OthW', 4).replace('Wall', 4)


#HeatingQC
train['HeatingQC'] = train['HeatingQC'].replace('Ex', 0).replace('Gd',1 ).replace('TA', 2).replace('Fa', 3).replace('Po', 4)


#CentralAir
train['CentralAir'] = train['CentralAir'].replace('N', 0).replace('Y',1 )


#Electrical
train['Electrical'] = train['Electrical'].replace('SBrkr', 0).replace('FuseA',1 ).replace('FuseF', 2).replace('FuseP', 3).replace('Mix', 4)


#KitchenQual
train['KitchenQual'] = train['KitchenQual'].replace('Ex', 0).replace('Gd',1 ).replace('TA', 2).replace('Fa', 3).replace('Po', 4)


#Functional
train['Functional'] = train['Functional'].replace('Typ', 0).replace('Min1',1 ).replace('Min2', 2).replace('Mod', 3).replace('Maj1', 4).replace('Maj2', 5).replace('Sev', 6).replace('Sal', 7)


#FireplaceQu
train['FireplaceQu'] = train['FireplaceQu'].replace('Ex', 0).replace('Gd',1 ).replace('TA', 2).replace('Fa', 3).replace('Po', 4).fillna(5)

#GarageType
train['GarageType'] = train['GarageType'].replace('2Types', 0).replace('Attchd',1 ).replace('Basment', 2).replace('BuiltIn', 3).replace('CarPort', 4).replace('Detchd', 5).fillna(6)


#GarageFinish
train['GarageFinish'] = train['GarageFinish'].replace('Fin', 0).replace('RFn',1 ).replace('Unf', 2).fillna(3)

#GarageQual
train['GarageQual'] = train['GarageQual'].replace('Ex', 0).replace('Gd',1 ).replace('TA', 2).replace('Fa', 3).replace('Po', 4).fillna(5)

#GarageCond
train['GarageCond'] = train['GarageCond'].replace('Ex', 0).replace('Gd',1 ).replace('TA', 2).replace('Fa', 3).replace('Po', 4).fillna(5)


#PavedDrive
train['PavedDrive'] = train['PavedDrive'].replace('Y', 0).replace('P', 1).replace('N', 2)


#PoolQC
train['PoolQC'] = train['PoolQC'].replace('Ex', 0).replace('Gd',1 ).replace('TA', 2).replace('Fa', 3).fillna(4)

#Fence
train['Fence'] = train['Fence'].replace('GdPrv', 0).replace('MnPrv',1 ).replace('GdWo', 2).replace('MnWw', 3).fillna(4)

#MiscFeature
train['MiscFeature'] = train['MiscFeature'].replace('Elev', 0).replace('Gar2',1 ).replace('Othr', 2).replace('Shed', 3).replace('TenC', 4).fillna(5)

#SaleType
train['SaleType'] = train['SaleType'].replace('WD', 0).replace('CWD',1 ).replace('VWD', 2).replace('New', 3).replace('COD', 4).replace('Con', 5).replace('ConLw', 6).replace('ConLI', 7).replace('ConLD', 8).replace('Oth', 9)

#SaleCondition
train['SaleCondition'] = train['SaleCondition'].replace('Normal', 0).replace('Abnorml',1 ).replace('AdjLand', 2).replace('Alloca', 3).replace('Family', 4).replace('Partial', 5)

# %% [markdown]
# ### 欠損値を平均で修正(train）

# %%
train['LotFrontage'] = train['LotFrontage'].fillna(train['LotFrontage'].mean())
train['MasVnrArea'] = train['MasVnrArea'].fillna(train['MasVnrArea'].mean())
train['GarageYrBlt'] = train['GarageYrBlt'].fillna(train['GarageYrBlt'].mean())
train['Electrical'] = train['Electrical'].fillna(0)

# %% [markdown]
# ### カテゴリ変数に変換（test）

# %%
# MSZoning
test['MSZoning'] = test['MSZoning'].replace('A', 0)
test['MSZoning'] = test['MSZoning'].replace(['C', 'C (all)'], 1)
test['MSZoning'] = test['MSZoning'].replace('FV', 2)
test['MSZoning'] = test['MSZoning'].replace('I', 3)
test['MSZoning'] = test['MSZoning'].replace('RH', 4)
test['MSZoning'] = test['MSZoning'].replace('RL', 5)
test['MSZoning'] = test['MSZoning'].replace('RP', 6)
test['MSZoning'] = test['MSZoning'].replace('RM', 7)

#Street
test['Street'] = test['Street'].replace('Grvl', 0)
test['Street'] = test['Street'].replace('Pave', 1)

# Alley
test['Alley'] = test['Alley'].replace('Grvl',0 )
test['Alley'] = test['Alley'].replace('Pave',1 )
test['Alley'] = test['Alley'].fillna(2 )

# LotShape
test['LotShape'] = test['LotShape'].replace('Reg', 0)
test['LotShape'] = test['LotShape'].replace('IR1', 1)
test['LotShape'] = test['LotShape'].replace('IR2', 2)
test['LotShape'] = test['LotShape'].replace('IR3', 3)

#LandContour
test['LandContour'] = test['LandContour'].replace('Lvl', 0)
test['LandContour'] = test['LandContour'].replace('Bnk',1 )
test['LandContour'] = test['LandContour'].replace('HLS', 2)
test['LandContour'] = test['LandContour'].replace('Low', 3)

#Utilities
test['Utilities'] = test['Utilities'].replace('AllPub',0 )
test['Utilities'] = test['Utilities'].replace('NoSewr', 1)
test['Utilities'] = test['Utilities'].replace('NoSeWa', 2)
test['Utilities'] = test['Utilities'].replace('ELO', 3)

# LotConfing
test['LotConfig'] = test['LotConfig'].replace('Inside', 0)
test['LotConfig'] = test['LotConfig'].replace('Corner', 1)
test['LotConfig'] = test['LotConfig'].replace('CulDSac',2 )
test['LotConfig'] = test['LotConfig'].replace('FR2',3 )
test['LotConfig'] = test['LotConfig'].replace('FR3', 4)


#LandSlope
test['LandSlope'] = test['LandSlope'].replace('Gtl', 0)
test['LandSlope'] = test['LandSlope'].replace('Mod', 1)
test['LandSlope'] = test['LandSlope'].replace('Sev', 2)

#Neighborhood
test['Neighborhood'] = test['Neighborhood'].replace('Blmngtn', 0 )
test['Neighborhood'] = test['Neighborhood'].replace('Blueste', 1)
test['Neighborhood'] = test['Neighborhood'].replace('BrDale', 2)
test['Neighborhood'] = test['Neighborhood'].replace('BrkSide', 3)
test['Neighborhood'] = test['Neighborhood'].replace('ClearCr', 4)
test['Neighborhood'] = test['Neighborhood'].replace('CollgCr', 5)
test['Neighborhood'] = test['Neighborhood'].replace('Crawfor', 6)
test['Neighborhood'] = test['Neighborhood'].replace('Edwards', 7)
test['Neighborhood'] = test['Neighborhood'].replace('Gilbert', 8)
test['Neighborhood'] = test['Neighborhood'].replace('IDOTRR',9 )
test['Neighborhood'] = test['Neighborhood'].replace('MeadowV',10 )
test['Neighborhood'] = test['Neighborhood'].replace('Mitchel', 11)
test['Neighborhood'] = test['Neighborhood'].replace('Names', 12)
test['Neighborhood'] = test['Neighborhood'].replace('NAmes', 12)
test['Neighborhood'] = test['Neighborhood'].replace('NWAmes', 12)
test['Neighborhood'] = test['Neighborhood'].replace('NoRidge', 13)
test['Neighborhood'] = test['Neighborhood'].replace('NPkVill', 14)
test['Neighborhood'] = test['Neighborhood'].replace('NridgHt', 15)
test['Neighborhood'] = test['Neighborhood'].replace('NtAmes', 16)
test['Neighborhood'] = test['Neighborhood'].replace('OldTown', 17)
test['Neighborhood'] = test['Neighborhood'].replace('SWISU', 18)
test['Neighborhood'] = test['Neighborhood'].replace('Sawyer', 19)
test['Neighborhood'] = test['Neighborhood'].replace('SawyerW', 20)
test['Neighborhood'] = test['Neighborhood'].replace('Somerst', 21)
test['Neighborhood'] = test['Neighborhood'].replace('StoneBr', 22)
test['Neighborhood'] = test['Neighborhood'].replace('Timber', 23)
test['Neighborhood'] = test['Neighborhood'].replace('Veenker', 24)


#Condition1
test['Condition1'] = test['Condition1'].replace('Artery', 0)
test['Condition1'] = test['Condition1'].replace('Feedr', 1)
test['Condition1'] = test['Condition1'].replace('Norm', 2)
test['Condition1'] = test['Condition1'].replace('RRNn', 3)
test['Condition1'] = test['Condition1'].replace('RRAn', 4)
test['Condition1'] = test['Condition1'].replace('PosN', 5)
test['Condition1'] = test['Condition1'].replace('PosA', 6)
test['Condition1'] = test['Condition1'].replace('RRNe', 7)
test['Condition1'] = test['Condition1'].replace('RRAe', 8)

#Condition2
test['Condition2'] = test['Condition2'].replace('Artery', 0)
test['Condition2'] = test['Condition2'].replace('Feedr', 1)
test['Condition2'] = test['Condition2'].replace('Norm', 2)
test['Condition2'] = test['Condition2'].replace('RRNn', 3)
test['Condition2'] = test['Condition2'].replace('RRAn', 4)
test['Condition2'] = test['Condition2'].replace('PosN', 5)
test['Condition2'] = test['Condition2'].replace('PosA', 6)
test['Condition2'] = test['Condition2'].replace('RRNe', 7)
test['Condition2'] = test['Condition2'].replace('RRAe', 8)

#BldgType
test['BldgType'] = test['BldgType'].replace('1Fam', 0)
test['BldgType'] = test['BldgType'].replace('2fmCon',1 )
test['BldgType'] = test['BldgType'].replace('2FmCon',1 )
test['BldgType'] = test['BldgType'].replace('Duplex', 2)
test['BldgType'] = test['BldgType'].replace('Duplx', 2)
test['BldgType'] = test['BldgType'].replace('Twnhs', 3)
test['BldgType'] = test['BldgType'].replace('TwnhsE', 3)
test['BldgType'] = test['BldgType'].replace('TwnhsI', 4)

#HouseStyle
test['HouseStyle'] = test['HouseStyle'].replace('1Story', 0)
test['HouseStyle'] = test['HouseStyle'].replace('1.5Fin', 1)
test['HouseStyle'] = test['HouseStyle'].replace('1.5Unf', 2)
test['HouseStyle'] = test['HouseStyle'].replace('2Story', 3)
test['HouseStyle'] = test['HouseStyle'].replace('2.5Fin', 4)
test['HouseStyle'] = test['HouseStyle'].replace('2.5Unf', 5)
test['HouseStyle'] = test['HouseStyle'].replace('SFoyer', 6)
test['HouseStyle'] = test['HouseStyle'].replace('SLvl', 7)

#RoofStyle
test['RoofStyle'] = test['RoofStyle'].replace('Flat',0 )
test['RoofStyle'] = test['RoofStyle'].replace('Gable', 1)
test['RoofStyle'] = test['RoofStyle'].replace('Gambrel', 2)
test['RoofStyle'] = test['RoofStyle'].replace('Hip',3 )
test['RoofStyle'] = test['RoofStyle'].replace('Mansard',4 )
test['RoofStyle'] = test['RoofStyle'].replace('Shed', 5)

#RoofMatl
test['RoofMatl'] = test['RoofMatl'].replace('ClyTile', 0)
test['RoofMatl'] = test['RoofMatl'].replace('CompShg',1 )
test['RoofMatl'] = test['RoofMatl'].replace('Membran', 2)
test['RoofMatl'] = test['RoofMatl'].replace('Metal', 3)
test['RoofMatl'] = test['RoofMatl'].replace('Roll', 4)
test['RoofMatl'] = test['RoofMatl'].replace('Tar&Grv', 5)
test['RoofMatl'] = test['RoofMatl'].replace('WdShake', 6)
test['RoofMatl'] = test['RoofMatl'].replace('WdShngl', 7)

#Exterior1st
test['Exterior1st'] = test['Exterior1st'].replace('AsbShng', 0)
test['Exterior1st'] = test['Exterior1st'].replace('AsphShn', 1)
test['Exterior1st'] = test['Exterior1st'].replace('BrkComm', 2)
test['Exterior1st'] = test['Exterior1st'].replace('BrkFace', 3)
test['Exterior1st'] = test['Exterior1st'].replace('CBlock', 4)
test['Exterior1st'] = test['Exterior1st'].replace('CemntBd', 5)
test['Exterior1st'] = test['Exterior1st'].replace('HdBoard', 6)
test['Exterior1st'] = test['Exterior1st'].replace('ImStucc', 7)
test['Exterior1st'] = test['Exterior1st'].replace('MetalSd', 8)
test['Exterior1st'] = test['Exterior1st'].replace('Other', 9)
test['Exterior1st'] = test['Exterior1st'].replace('Plywood', 10)
test['Exterior1st'] = test['Exterior1st'].replace('PreCast', 11)
test['Exterior1st'] = test['Exterior1st'].replace('Stone', 12)
test['Exterior1st'] = test['Exterior1st'].replace('Stucco', 13)
test['Exterior1st'] = test['Exterior1st'].replace('VinylSd', 14)
test['Exterior1st'] = test['Exterior1st'].replace('Wd Sdng', 15)
test['Exterior1st'] = test['Exterior1st'].replace('WdShing', 16)


#Exterior2nd
test['Exterior2nd'] = test['Exterior2nd'].replace('AsbShng', 0)
test['Exterior2nd'] = test['Exterior2nd'].replace('AsphShn', 1)
test['Exterior2nd'] = test['Exterior2nd'].replace('BrkComm', 2)
test['Exterior2nd'] = test['Exterior2nd'].replace('Brk Cmn', 2)
test['Exterior2nd'] = test['Exterior2nd'].replace('Brk Cmm', 2)
test['Exterior2nd'] = test['Exterior2nd'].replace('BrkFace', 3)
test['Exterior2nd'] = test['Exterior2nd'].replace('CBlock', 4)
test['Exterior2nd'] = test['Exterior2nd'].replace('CemntBd', 5)
test['Exterior2nd'] = test['Exterior2nd'].replace('CmentBd', 5)
test['Exterior2nd'] = test['Exterior2nd'].replace('HdBoard', 6)
test['Exterior2nd'] = test['Exterior2nd'].replace('ImStucc', 7)
test['Exterior2nd'] = test['Exterior2nd'].replace('MetalSd', 8)
test['Exterior2nd'] = test['Exterior2nd'].replace('Other', 9)
test['Exterior2nd'] = test['Exterior2nd'].replace('Plywood', 10)
test['Exterior2nd'] = test['Exterior2nd'].replace('PreCast', 11)
test['Exterior2nd'] = test['Exterior2nd'].replace('Stone', 12)
test['Exterior2nd'] = test['Exterior2nd'].replace('Stucco', 13)
test['Exterior2nd'] = test['Exterior2nd'].replace('VinylSd', 14)
test['Exterior2nd'] = test['Exterior2nd'].replace('Wd Sdng', 15)
test['Exterior2nd'] = test['Exterior2nd'].replace('WdShing', 16)
test['Exterior2nd'] = test['Exterior2nd'].replace('Wd Shng', 16)

#MasVnrType
test['MasVnrType'] = test['MasVnrType'].replace('BrkCmn', 0)
test['MasVnrType'] = test['MasVnrType'].replace('BrkFace', 1)
test['MasVnrType'] = test['MasVnrType'].replace('CBlock', 2)
test['MasVnrType'] = test['MasVnrType'].fillna(3)
test['MasVnrType'] = test['MasVnrType'].replace('None', 3)
test['MasVnrType'] = test['MasVnrType'].replace('Stone', 4)


#ExterQual
test['ExterQual'] = test['ExterQual'].replace('Ex', 0).replace('Gd',1 ).replace('TA', 2).replace('Fa', 3).replace('Po', 4)

#ExterCond
test['ExterCond'] = test['ExterCond'].replace('Ex', 0).replace('Gd',1 ).replace('TA', 2).replace('Fa', 3).replace('Po', 4)

#Foundation
test['Foundation'] = test['Foundation'].replace('BrkTil', 0).replace('CBlock',1 ).replace('PConc', 2).replace('Slab', 3).replace('Stone', 4).replace('Wood', 5)

#BsmtQual
test['BsmtQual'] = test['BsmtQual'].replace('Ex', 0).replace('Gd',1 ).replace('TA', 2).replace('Fa', 3).replace('Po', 4).fillna(5)

#BsmtCond
test['BsmtCond'] = test['BsmtCond'].replace('Ex', 0).replace('Gd',1 ).replace('TA', 2).replace('Fa', 3).replace('Po', 4).fillna(5)


#BsmtExposure
test['BsmtExposure'] = test['BsmtExposure'].replace('Gd', 0).replace('Av',1 ).replace('Mn', 2).replace('No', 3).fillna(4)


#BsmtFinType1
test['BsmtFinType1'] = test['BsmtFinType1'].replace('GLQ', 0).replace('ALQ',1 ).replace('BLQ', 2).replace('Rec', 3).replace('LwQ', 4).replace('Unf', 5).fillna(6)


#BsmtFinType2
test['BsmtFinType2'] = test['BsmtFinType1'].replace('GLQ', 0).replace('ALQ',1 ).replace('BLQ', 2).replace('Rec', 3).replace('LwQ', 4).replace('Unf', 5).fillna(6)


#Heating
test['Heating'] = test['Heating'].replace('Floor', 0).replace('GasA',1 ).replace('GasW', 2).replace('Grav', 3).replace('OthW', 4).replace('Wall', 4)


#HeatingQC
test['HeatingQC'] = test['HeatingQC'].replace('Ex', 0).replace('Gd',1 ).replace('TA', 2).replace('Fa', 3).replace('Po', 4)


#CentralAir
test['CentralAir'] = test['CentralAir'].replace('N', 0).replace('Y',1 )


#Electrical
test['Electrical'] = test['Electrical'].replace('SBrkr', 0).replace('FuseA',1 ).replace('FuseF', 2).replace('FuseP', 3).replace('Mix', 4)


#KitchenQual
test['KitchenQual'] = test['KitchenQual'].replace('Ex', 0).replace('Gd',1 ).replace('TA', 2).replace('Fa', 3).replace('Po', 4)


#Functional
test['Functional'] = test['Functional'].replace('Typ', 0).replace('Min1',1 ).replace('Min2', 2).replace('Mod', 3).replace('Maj1', 4).replace('Maj2', 5).replace('Sev', 6).replace('Sal', 7)


#FireplaceQu
test['FireplaceQu'] = test['FireplaceQu'].replace('Ex', 0).replace('Gd',1 ).replace('TA', 2).replace('Fa', 3).replace('Po', 4).fillna(5)

#GarageType
test['GarageType'] = test['GarageType'].replace('2Types', 0).replace('Attchd',1 ).replace('Basment', 2).replace('BuiltIn', 3).replace('CarPort', 4).replace('Detchd', 5).fillna(6)


#GarageFinish
test['GarageFinish'] = test['GarageFinish'].replace('Fin', 0).replace('RFn',1 ).replace('Unf', 2).fillna(3)

#GarageQual
test['GarageQual'] = test['GarageQual'].replace('Ex', 0).replace('Gd',1 ).replace('TA', 2).replace('Fa', 3).replace('Po', 4).fillna(5)

#GarageCond
test['GarageCond'] = test['GarageCond'].replace('Ex', 0).replace('Gd',1 ).replace('TA', 2).replace('Fa', 3).replace('Po', 4).fillna(5)


#PavedDrive
test['PavedDrive'] = test['PavedDrive'].replace('Y', 0).replace('P', 1).replace('N', 2)


#PoolQC
test['PoolQC'] = test['PoolQC'].replace('Ex', 0).replace('Gd',1 ).replace('TA', 2).replace('Fa', 3).fillna(4)

#Fence
test['Fence'] = test['Fence'].replace('GdPrv', 0).replace('MnPrv',1 ).replace('GdWo', 2).replace('MnWw', 3).fillna(4)

#MiscFeature
test['MiscFeature'] = test['MiscFeature'].replace('Elev', 0).replace('Gar2',1 ).replace('Othr', 2).replace('Shed', 3).replace('TenC', 4).fillna(5)

#SaleType
test['SaleType'] = test['SaleType'].replace('WD', 0).replace('CWD',1 ).replace('VWD', 2).replace('New', 3).replace('COD', 4).replace('Con', 5).replace('ConLw', 6).replace('ConLI', 7).replace('ConLD', 8).replace('Oth', 9)

#SaleCondition
test['SaleCondition'] = test['SaleCondition'].replace('Normal', 0).replace('Abnorml',1 ).replace('AdjLand', 2).replace('Alloca', 3).replace('Family', 4).replace('Partial', 5)

# %% [markdown]
# ### 欠損値を平均で修正(test）

# %%
test['LotFrontage'] = test['LotFrontage'].fillna(test['LotFrontage'].mean())
test['MasVnrArea'] = test['MasVnrArea'].fillna(test['MasVnrArea'].mean())
test['GarageYrBlt'] = test['GarageYrBlt'].fillna(test['GarageYrBlt'].mean())
test['MSZoning'] = test['MSZoning'].fillna(test['MSZoning'].mean())
test['Utilities'] = test['Utilities'].fillna(test['Utilities'].mean())
test['Exterior1st'] = test['Exterior1st'].fillna(test['Exterior1st'].mean())
test['Exterior2nd'] = test['Exterior2nd'].fillna(test['Exterior2nd'].mean())
test['KitchenQual'] = test['KitchenQual'].fillna(test['KitchenQual'].mean())
test['Functional'] = test['Functional'].fillna(test['Functional'].mean())
test['GarageCars'] = test['GarageCars'].fillna(test['GarageCars'].mean())
test['GarageArea'] = test['GarageArea'].fillna(test['GarageArea'].mean())
test['SaleType'] = test['SaleType'].fillna(test['SaleType'].mean())

#テストの#662だけ当て果ては待っているのでドロップした方が良いかも
test['BsmtFinSF1'] = test['BsmtFinSF1'].fillna(test['BsmtFinSF1'].mean())
test['BsmtFinSF2'] = test['BsmtFinSF2'].fillna(test['BsmtFinSF2'].mean())
test['BsmtUnfSF'] = test['BsmtUnfSF'].fillna(test['BsmtUnfSF'].mean())
test['TotalBsmtSF'] = test['TotalBsmtSF'].fillna(test['TotalBsmtSF'].mean())
test['BsmtFullBath'] = test['BsmtFullBath'].fillna(test['BsmtFullBath'].mean())
test['BsmtHalfBath'] = test['BsmtHalfBath'].fillna(test['BsmtHalfBath'].mean())

# %% [markdown]
# ## floatデータを修正

# %%
# train
train = train.astype('int')

#test
test = test.astype('int')

# %% [markdown]
# ## 訓練用データ・テストデータ作成

# %%
x_train = train.iloc[:, 0:80]
y_train = train.iloc[:, 80]

# %%
x_test = test

# %%
#確認用エクセル吐き出し（train）
train.to_excel('missing_value_verify.xlsx', index = False)

# %%
#確認用エクセル吐き出し（test）
test.to_excel('missing_value_verify_test.xlsx', index = False)

# %% [markdown]
# ## モデル作成

# %%
import xgboost as xgb
import lightgbm as lgb
from catboost import CatBoostRegressor
from multiprocessing import *

# %%
import pandas as pd 
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVR, LinearSVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor
import lightgbm as lgb
from lightgbm import LGBMRegressor
from xgboost  import XGBRegressor
import xgboost as xgb

from sklearn.model_selection import cross_val_score

# %%
params = {
        'task': 'train',
        'boosting_type': 'gbdt',
        'objective': 'multiclass',
        'metric': {'multi_logloss'},
        'num_class': 3,
        'learning_rate': 0.1,
        'num_leaves': 23,
        'min_data_in_leaf': 1,
        'num_iteration': 100,
        'verbose': 0
}
models = []

# models.append(("LogisticRegression",LogisticRegression()))
# models.append(("SVC",SVR()))
# models.append(("LinearSVC",LinearSVR()))
# models.append(("KNeighbors",KNeighborsRegressor()))
# models.append(("DecisionTree",DecisionTreeRegressor()))
# models.append(("RandomForest",RandomForestRegressor()))
# models.append(("MLPClassifier",MLPRegressor()))
models.append(("lightGBM", LGBMRegressor(objective='regression') ))
models.append(("XGBOOST", XGBRegressor()))

# %%
results = []
names = []
for name, model in models:
    result = cross_val_score(model, x_train, y_train, cv = 3, scoring='mean_squared_error',)
    names.append(name)
    results.append(result)
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/metrics/scorer.py:100: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda3/lib/python3.6/site-packages/sklearn/metrics/scorer.py:100: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda3/lib/python3.6/site-packages/sklearn/metrics/scorer.py:100: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda3/lib/python3.6/site-packages/sklearn/metrics/scorer.py:100: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# ...

# %%
for i in range(len(names)):
    print(names[i], results[i].mean())
# Out:
# lightGBM -820584750.7218175
# XGBOOST -771483033.1705756

# %%
#　グリッドサーチでハイパラ求めた時のXGBOOSTのMSE
LogisticRegression -3643118063.4929366
SVC -6648777657.830586
LinearSVC -1062534000594.8202
KNeighbors -2352333450.010224
DecisionTree -2091221285.632552
RandomForest -976242274.3680496
MLPClassifier -6845431894.683444
lightGBM -820584750.7218175
XGBOOST -663483069.1264185

# %% [markdown]
# ## グリッドサーチ

# %%
##組み合わせ多すぎてめっちゃ時間かかる！！

from sklearn.grid_search import GridSearchCV
from sklearn import grid_search

params = {"learning_rate":[0.01, 0.02, 0.03, 0.1,0.3],
        "max_depth": [2,3,5,6, 7, 8, 10],
         "subsample":[0.5,0.8,0.9,1],
         "colsample_bytree": [0.5,1.0],
          "n_estimators":[100, 200, 300, 400, 500],
          "min_child_weight":[0.5, 0.75, 1]
         }

mod = grid_search.GridSearchCV(XGBRegressor(), params, cv = 3, n_jobs=-1, scoring="mean_squared_error")
mod.fit(x_train, y_train)

print(mod.best_estimator_)
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/metrics/scorer.py:100: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda3/lib/python3.6/site-packages/sklearn/metrics/scorer.py:100: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda3/lib/python3.6/site-packages/sklearn/metrics/scorer.py:100: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda3/lib/python3.6/site-packages/sklearn/metrics/scorer.py:100: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# ...

# %%
# ?GridSearchCV
